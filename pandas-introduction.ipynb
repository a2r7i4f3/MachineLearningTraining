# %%
import pandas as pd

# %%
series = pd.Series(["Arif","Samsul","Bangladesh"])

# %%
series
# Out:
# 0          Arif
# 1        Samsul
# 2    Bangladesh
# dtype: object

# %%
colors = pd.Series(["Red","Blue","Green"])

# %%
man_data = pd.DataFrame({"Man Make":series,"Color":colors})

# %%
man_data
# Out:
#      Man Make  Color
# 0        Arif    Red
# 1      Samsul   Blue
# 2  Bangladesh  Green

# %%
books = pd.Series(["C","D","E"])

# %%
price = pd.Series([100,200,300])
price
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
books_data = pd.DataFrame({"Books:":books, "Price: ": price})
books_data
# Out:
#   Books:  Price:
# 0      C      100
# 1      D      200
# 2      E      300

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
export_from_csv = car_sales.to_csv("exported-car-sales.csv", index=False)
export_from_csv

# %%
export_from_csv

# %%
pd.read_csv("exported-car-sales.csv")
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe Data

# %%
#Attribute
#but not a fuction , function is # car_sales.read_csv()

car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()   #statistical information of numerical column
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_price = pd.Series([10000,299999,43333])

# %%
car_price.mean()
# Out:
# 117777.33333333333

# %%
car_price.sum()
# Out:
# 353332

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
car_sales['Price'].sum()
# Out:
# '$4,000.00$5,000.00$7,000.00$22,000.00$3,500.00$4,500.00$7,500.00$7,000.00$6,250.00$9,700.00'

# %%
len(car_sales)
# Out:
# 10

# %% [markdown]
# ## Viewing and selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(1)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00

# %%
car_sales.head(6)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(1)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 9  Nissan  White          31600      4  $9,700.00

# %%
names = pd.Series(["Arif","Shimul","Nunu","Samsu","Forhad"])

# %%
names
# Out:
# 0      Arif
# 1    Shimul
# 2      Nunu
# 3     Samsu
# 4    Forhad
# dtype: object

# %%
colors = pd.Series(["Red","Blue","Green"],index=[0,4,3])

# %%
colors
# Out:
# 0      Red
# 4     Blue
# 3    Green
# dtype: object

# %%
colors.loc[3]
# Out:
# 'Green'

# %%
colors
# Out:
# 0      Red
# 4     Blue
# 3    Green
# dtype: object

# %%
colors.drop
(2
)
# Out:
# 2

# %%
colors
# Out:
# 0      Red
# 4     Blue
# 3    Green
# dtype: object

# %%
car_sales[car_sales["Make"]=="Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Doors"].plot()

# %%
car_sales.groupby(["Doors"]).sum()
# Out:
#        Odometer (KM)
# Doors
# 3              32549
# 4             742286
# 5              11179

# %%
car_sales.groupby("Make").median()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW           11179.0    5.0
# Honda         54738.0    4.0
# Nissan       122347.5    4.0
# Toyota        79606.5    4.0

# %%
car_sales.groupby("Make").median().plot()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price    price
# 0  Toyota  White         150043      4   400000   400000
# 1   Honda    Red          87899      4   500000   500000
# 2  Toyota   Blue          32549      3   700000   700000
# 3     BMW  Black          11179      5  2200000  2200000
# 4  Nissan  White         213095      4   350000   350000
# 5  Toyota  Green          99213      4   450000   450000
# 6   Honda   Blue          45698      4   750000   750000
# 7   Honda   Blue          54738      4   700000   700000
# 8  Toyota  White          60000      4   625000   625000
# 9  Nissan  White          31600      4   970000   970000

# %% [markdown]
# ## Manipulating Data

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price    price
# 0  Toyota  White         150043      4   400000   400000
# 1   Honda    Red          87899      4   500000   500000
# 2  Toyota   Blue          32549      3   700000   700000
# 3     BMW  Black          11179      5  2200000  2200000
# 4  Nissan  White         213095      4   350000   350000
# 5  Toyota  Green          99213      4   450000   450000
# 6   Honda   Blue          45698      4   750000   750000
# 7   Honda   Blue          54738      4   700000   700000
# 8  Toyota  White          60000      4   625000   625000
# 9  Nissan  White          31600      4   970000   970000

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price    price
# 0  toyota  White         150043      4   400000   400000
# 1   honda    Red          87899      4   500000   500000
# 2  toyota   Blue          32549      3   700000   700000
# 3     bmw  Black          11179      5  2200000  2200000
# 4  nissan  White         213095      4   350000   350000
# 5  toyota  Green          99213      4   450000   450000
# 6   honda   Blue          45698      4   750000   750000
# 7   honda   Blue          54738      4   700000   700000
# 8  toyota  White          60000      4   625000   625000
# 9  nissan  White          31600      4   970000   970000

# %%
 car_sales = car_sales.drop("price", axis = 1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv('car-sales-extended-missing-data.csv)
# Out:
#   File "<ipython-input-93-8490b492a2f2>", line 1
#     car_sales_missing = pd.read_csv('car-sales-extended-missing-data.csv)
#                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
pd.read_csv("car-sales-extended-missing-data.csv")
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing = pd.read_csv("car-sales-extended-missing-data.csv")

# %% [markdown]
# car_sales_misssing

# %%
car_sales_missing
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing.head(20)
# Out:
#       Make Colour  Odometer (KM)  Doors    Price
# 0    Honda  White        35431.0    4.0  15323.0
# 1      BMW   Blue       192714.0    5.0  19943.0
# 2    Honda  White        84714.0    4.0  28343.0
# 3   Toyota  White       154365.0    4.0  13434.0
# 4   Nissan   Blue       181577.0    3.0  14043.0
# 5    Honda    Red        42652.0    4.0  23883.0
# 6   Toyota   Blue       163453.0    4.0   8473.0
# 7    Honda  White            NaN    4.0  20306.0
# 8      NaN  White       130538.0    4.0   9374.0
# 9    Honda   Blue        51029.0    4.0  26683.0
# 10  Nissan  White       167421.0    4.0  16259.0
# 11  Nissan  Green        17119.0    4.0   6160.0
# 12  Nissan  White       102303.0    4.0  16909.0
# 13     NaN  White       134181.0    4.0  11121.0
# 14   Honda   Blue       199833.0    4.0  18946.0
# 15  Toyota   Blue       205592.0    4.0  16290.0
# 16  Toyota    Red        96742.0    4.0  34465.0
# 17     BMW  White       194189.0    5.0  17177.0
# 18  Nissan  White        67991.0    3.0   9109.0
# 19  Nissan   Blue       215820.0    4.0   6010.0

# %%
car_sales_missing.to_csv("missing_data.csv")

# %%
fuel_economy = [1.4, 2.5, 4.6, 7.8, 9.1, 10.20, 20.20, 23.5, 1.5, 3.4]
car_sales["Fuel per 100KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM
# 0  toyota  White         150043      4   400000             1.4
# 1   honda    Red          87899      4   500000             2.5
# 2  toyota   Blue          32549      3   700000             4.6
# 3     bmw  Black          11179      5  2200000             7.8
# 4  nissan  White         213095      4   350000             9.1
# 5  toyota  Green          99213      4   450000            10.2
# 6   honda   Blue          45698      4   750000            20.2
# 7   honda   Blue          54738      4   700000            23.5
# 8  toyota  White          60000      4   625000             1.5
# 9  nissan  White          31600      4   970000             3.4

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             1.4
# 1   honda    Red          87899      4   500000             2.5
# 2  toyota   Blue          32549      3   700000             4.6
# 3     bmw  Black          11179      5  2200000             7.8
# 4  nissan  White         213095      4   350000             9.1
# 5  toyota  Green          99213      4   450000            10.2
# 6   honda   Blue          45698      4   750000            20.2
# 7   honda   Blue          54738      4   700000            23.5
# 8  toyota  White          60000      4   625000             1.5
# 9  nissan  White          31600      4   970000             3.4
#
#    Total fuel used
# 0         2100.602
# 1         2197.475
# 2         1497.254
# 3          871.962
# 4        19391.645
# 5        10119.726
# 6         9230.996
# 7        12863.430
# 8          900.000
# 9         1074.400

# %%
car_sales.to_csv("Exported.csv")

# %%
pd.read_csv("Exported.csv")
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0           0  toyota  White         150043      4   400000             1.4
# 1           1   honda    Red          87899      4   500000             2.5
# 2           2  toyota   Blue          32549      3   700000             4.6
# 3           3     bmw  Black          11179      5  2200000             7.8
# 4           4  nissan  White         213095      4   350000             9.1
# 5           5  toyota  Green          99213      4   450000            10.2
# 6           6   honda   Blue          45698      4   750000            20.2
# 7           7   honda   Blue          54738      4   700000            23.5
# 8           8  toyota  White          60000      4   625000             1.5
# 9           9  nissan  White          31600      4   970000             3.4
#
#    Total fuel used
# 0         2100.602
# 1         2197.475
# 2         1497.254
# 3          871.962
# 4        19391.645
# 5        10119.726
# 6         9230.996
# 7        12863.430
# 8          900.000
# 9         1074.400

# %%
# create a column using single value

car_sales["Number of wheel"] = 4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             1.4
# 1   honda    Red          87899      4   500000             2.5
# 2  toyota   Blue          32549      3   700000             4.6
# 3     bmw  Black          11179      5  2200000             7.8
# 4  nissan  White         213095      4   350000             9.1
# 5  toyota  Green          99213      4   450000            10.2
# 6   honda   Blue          45698      4   750000            20.2
# 7   honda   Blue          54738      4   700000            23.5
# 8  toyota  White          60000      4   625000             1.5
# 9  nissan  White          31600      4   970000             3.4
#
#    Total fuel used  Number of wheel
# 0         2100.602                4
# 1         2197.475                4
# 2         1497.254                4
# 3          871.962                4
# 4        19391.645                4
# 5        10119.726                4
# 6         9230.996                4
# 7        12863.430                4
# 8          900.000                4
# 9         1074.400                4

# %%
car_sales.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-112-fa14edc64836> in <module>
# ----> 1 car_sales.dtype
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             1.4
# 1   honda    Red          87899      4   500000             2.5
# 2  toyota   Blue          32549      3   700000             4.6
# 3     bmw  Black          11179      5  2200000             7.8
# 4  nissan  White         213095      4   350000             9.1
# 5  toyota  Green          99213      4   450000            10.2
# 6   honda   Blue          45698      4   750000            20.2
# 7   honda   Blue          54738      4   700000            23.5
# 8  toyota  White          60000      4   625000             1.5
# 9  nissan  White          31600      4   970000             3.4
#
#    Total fuel used  Number of wheel
# 0         2100.602                4
# 1         2197.475                4
# 2         1497.254                4
# 3          871.962                4
# 4        19391.645                4
# 5        10119.726                4
# 6         9230.996                4
# 7        12863.430                4
# 8          900.000                4
# 9         1074.400                4

# %%
car_sales.dtypes
# Out:
# Make                object
# Colour              object
# Odometer (KM)        int64
# Doors                int64
# Price                int64
# Fuel per 100KM     float64
# Total fuel used    float64
# Number of wheel      int64
# dtype: object

# %%
car_sales["values"] = True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             1.4
# 1   honda    Red          87899      4   500000             2.5
# 2  toyota   Blue          32549      3   700000             4.6
# 3     bmw  Black          11179      5  2200000             7.8
# 4  nissan  White         213095      4   350000             9.1
# 5  toyota  Green          99213      4   450000            10.2
# 6   honda   Blue          45698      4   750000            20.2
# 7   honda   Blue          54738      4   700000            23.5
# 8  toyota  White          60000      4   625000             1.5
# 9  nissan  White          31600      4   970000             3.4
#
#    Total fuel used  Number of wheel  values
# 0         2100.602                4    True
# 1         2197.475                4    True
# 2         1497.254                4    True
# 3          871.962                4    True
# 4        19391.645                4    True
# 5        10119.726                4    True
# 6         9230.996                4    True
# 7        12863.430                4    True
# 8          900.000                4    True
# 9         1074.400                4    True

# %%
car_sales.sample(frac = 1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 8  toyota  White          60000      4   625000             1.5
# 4  nissan  White         213095      4   350000             9.1
# 2  toyota   Blue          32549      3   700000             4.6
# 5  toyota  Green          99213      4   450000            10.2
# 3     bmw  Black          11179      5  2200000             7.8
# 6   honda   Blue          45698      4   750000            20.2
# 9  nissan  White          31600      4   970000             3.4
# 1   honda    Red          87899      4   500000             2.5
# 7   honda   Blue          54738      4   700000            23.5
# 0  toyota  White         150043      4   400000             1.4
#
#    Total fuel used  Number of wheel  values
# 8          900.000                4    True
# 4        19391.645                4    True
# 2         1497.254                4    True
# 5        10119.726                4    True
# 3          871.962                4    True
# 6         9230.996                4    True
# 9         1074.400                4    True
# 1         2197.475                4    True
# 7        12863.430                4    True
# 0         2100.602                4    True

# %%
car_sales_shuffled = car_sales.sample(frac = 0.5)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Fuel per 100KM  \
# 8  toyota  White          60000      4  625000             1.5
# 6   honda   Blue          45698      4  750000            20.2
# 2  toyota   Blue          32549      3  700000             4.6
# 7   honda   Blue          54738      4  700000            23.5
# 9  nissan  White          31600      4  970000             3.4
#
#    Total fuel used  Number of wheel  values
# 8          900.000                4    True
# 6         9230.996                4    True
# 2         1497.254                4    True
# 7        12863.430                4    True
# 9         1074.400                4    True

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000             1.4
# 1   honda    Red          87899      4   500000             2.5
# 2  toyota   Blue          32549      3   700000             4.6
# 3     bmw  Black          11179      5  2200000             7.8
# 4  nissan  White         213095      4   350000             9.1
# 5  toyota  Green          99213      4   450000            10.2
# 6   honda   Blue          45698      4   750000            20.2
# 7   honda   Blue          54738      4   700000            23.5
# 8  toyota  White          60000      4   625000             1.5
# 9  nissan  White          31600      4   970000             3.4
#
#    Total fuel used  Number of wheel  values
# 0         2100.602                4    True
# 1         2197.475                4    True
# 2         1497.254                4    True
# 3          871.962                4    True
# 4        19391.645                4    True
# 5        10119.726                4    True
# 6         9230.996                4    True
# 7        12863.430                4    True
# 8          900.000                4    True
# 9         1074.400                4    True

# %%
car_sales_shuffled.reset_index(drop = True)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Fuel per 100KM  \
# 0  toyota  White          60000      4  625000             1.5
# 1   honda   Blue          45698      4  750000            20.2
# 2  toyota   Blue          32549      3  700000             4.6
# 3   honda   Blue          54738      4  700000            23.5
# 4  nissan  White          31600      4  970000             3.4
#
#    Total fuel used  Number of wheel  values
# 0          900.000                4    True
# 1         9230.996                4    True
# 2         1497.254                4    True
# 3        12863.430                4    True
# 4         1074.400                4    True

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0  toyota  White      93776.875      4   400000             1.4
# 1   honda    Red      54936.875      4   500000             2.5
# 2  toyota   Blue      20343.125      3   700000             4.6
# 3     bmw  Black       6986.875      5  2200000             7.8
# 4  nissan  White     133184.375      4   350000             9.1
# 5  toyota  Green      62008.125      4   450000            10.2
# 6   honda   Blue      28561.250      4   750000            20.2
# 7   honda   Blue      34211.250      4   700000            23.5
# 8  toyota  White      37500.000      4   625000             1.5
# 9  nissan  White      19750.000      4   970000             3.4
#
#    Total fuel used  Number of wheel  values
# 0         2100.602                4    True
# 1         2197.475                4    True
# 2         1497.254                4    True
# 3          871.962                4    True
# 4        19391.645                4    True
# 5        10119.726                4    True
# 6         9230.996                4    True
# 7        12863.430                4    True
# 8          900.000                4    True
# 9         1074.400                4    True

# %%
car_sales.plot()

# %%
car_sales.groupby(["Price"]).sum().plot()
